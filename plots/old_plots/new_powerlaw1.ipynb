# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
# plt.rcParams['text.usetex'] = False
import matplotlib.cm as cm
colormap = cm.get_cmap("hsv")
# Out:
# C:\Users\alexk\AppData\Local\Temp\ipykernel_19352\3687537565.py:6: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = cm.get_cmap("hsv")

# %%
x=torch.tensor([[[19.4190],
         [35.0750],
         [86.0363],
         [97.1933],
         [98.9550],
         [99.4763],
         [99.7603]],

        [[12.8147],
         [15.8450],
         [22.2033],
         [84.0250],
         [98.6297],
         [99.7590],
         [99.9347]],

        [[11.6827],
         [13.5537],
         [16.4090],
         [60.8030],
         [99.6113],
         [99.9553],
         [99.9910]]]).squeeze()
x
# Out:
# tensor([[19.4190, 35.0750, 86.0363, 97.1933, 98.9550, 99.4763, 99.7603],
#         [12.8147, 15.8450, 22.2033, 84.0250, 98.6297, 99.7590, 99.9347],
#         [11.6827, 13.5537, 16.4090, 60.8030, 99.6113, 99.9553, 99.9910]])

# %%
import matplotlib.cm as cm
colormap = cm.get_cmap("hsv")


layer3_overlapping_duplicate=np.array([[10.58, 12.22, 15.1, 17.88, 27.96, 67.95, 96.7, 98.99, 99.62, 99.86, 99.94, 99.96],
 [10.15, 10.26, 11.33, 11.6, 15.25, 22.94, 69.97, 97.35, 99.9, 100.0, 100.0, 100.0],
 [10.33, 9.88, 10.11, 11.73, 13.12, 16.34, 36.02, 99.75, 100.0, 100.0, 100.0, 100.0],
 [10.05, 10.41, 9.97, 10.3, 12.86, 14.74, 23.52, 99.79, 100.0, 100.0, 100.0, 100.0]])
layer3_zipf_LCN=torch.tensor([[19.4190, 35.0750, 86.0363, 97.1933, 98.9550, 99.4763, 99.7603],
        [12.8147, 15.8450, 22.2033, 84.0250, 98.6297, 99.7590, 99.9347],
        [11.6827, 13.5537, 16.4090, 60.8030, 99.6113, 99.9553, 99.9910]])
layer3_accurate_sim=np.array([[4.6997e-02, 2.3200e-01, 1.1980e+00, 6.6640e+00, 3.2416e+01, 8.0171e+01,
        8.9423e+01, 9.3491e+01, 9.7805e+01, 9.9057e+01],[0.0000e+00, 0.0000e+00, 5.9998e-02, 3.8000e-01, 2.2800e+00, 1.5090e+01,
        4.4670e+01, 7.3320e+01, 9.3360e+01, 9.9610e+01],[0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0002e-02, 5.0000e-01, 5.2700e+00,
        3.0710e+01, 7.2750e+01, 9.7360e+01, 1.0000e+02]])
for i in range(3):
  # plt.loglog(np.logspace(1,5.5,10),1-0.01*layer3_accurate_sim[i,:],color=colormap(i/3+0),linestyle="dotted",marker='o')
  # plt.loglog(np.logspace(2.5,5.5,7),1-0.01*layer3_zipf_LCN[i,:],color=colormap(i/3+0),linestyle="solid",marker="o")
  plt.loglog(np.logspace(1,6.5,12),1-0.01*layer3_overlapping_duplicate[i,:],color=colormap(i/3+0),linestyle="solid",linewidth=2,marker="o")
uniform_result=np.array([12.56, 13.39, 14.5, 15.96, 19.94, 39.42, 95.62, 99.96, 100.0, 100.0])
plt.plot(np.logspace(3,5,10),1-0.01*uniform_result, color="black")

layer1_zipf=np.array([[11.0900, 11.1200, 13.5700, 16.8500, 45.2300, 87.2800, 96.6200, 98.5100, 99.4100, 99.6900],
[ 10.2000,  10.8300,  11.2900,  13.7700,  20.3600,  36.6400,  77.2000, 95.9200,  99.8300, 100.0000],
[  9.7500,  10.2900,  10.5400,  12.6200,  16.1400,  22.7700,  59.3900, 98.0100,  99.9500, 100.0000]])
layer1_zipf_LCN=torch.Tensor([[19.5677, 40.1657, 86.2673, 96.6120, 98.4527, 99.4367, 99.7380],
        [13.9947, 19.6750, 31.2937, 78.0963, 97.8117, 99.7480, 99.9793],
        [12.1630, 14.7070, 19.6990, 55.6567, 99.3803, 99.9640, 99.9937]])
accurate_layer1_sim=np.array([[0.0000e+00, 0.0000e+00, 1.9997e-02, 7.4000e-01, 1.5140e+01, 7.8150e+01,
        9.6470e+01, 9.6770e+01, 9.8980e+01, 9.9570e+01],[0.0000e+00, 0.0000e+00, 1.0002e-02, 1.4000e-01, 3.0000e+00, 3.2390e+01,
        6.7520e+01, 8.4950e+01, 9.5040e+01, 9.9660e+01],[0.0000e+00, 0.0000e+00, 0.0000e+00, 1.9997e-02, 6.6000e-01, 1.2790e+01,
        4.9710e+01, 7.9700e+01, 9.7880e+01, 1.0000e+02]])
for i in range(3):
  plt.loglog(np.logspace(2.5,5.5,7),1-0.01*layer1_zipf_LCN[i,:],color=colormap(i/3+0),linestyle="solid",marker='x')
  # plt.loglog(np.logspace(1,5.5,10),1-0.01*accurate_layer1_sim[i,:],color=colormap(i/3+0),linestyle="dotted",linewidth=2,marker='x')

layer2_zipf=np.array([[ 10.4200,  11.3900,  13.6800,  18.4500,  29.1800,  92.6400,  96.6500,
          99.0200,  99.5800,  99.8100],
        [ 10.2900,  11.4600,  12.0500,  14.3200,  20.2300,  32.7000,  76.7300,
          95.3800,  99.8200,  99.9700],
        [ 10.7300,  11.2200,  10.2000,  12.1700,  16.5400,  20.9300,  57.7600,
          98.7400,  99.9800, 100.0000]])
accurate_layer2_sim=np.array([[0.0000e+00, 1.0002e-02, 8.9996e-02, 1.1600e+00, 1.7900e+01, 7.7470e+01,
        9.3570e+01, 9.5360e+01, 9.8420e+01, 9.9360e+01],[0.0000e+00, 0.0000e+00, 0.0000e+00, 8.9996e-02, 2.2900e+00, 2.1830e+01,
        5.5290e+01, 7.8790e+01, 9.4250e+01, 9.9570e+01],[0.0000e+00, 0.0000e+00, 0.0000e+00, 4.0001e-02, 6.1000e-01, 7.3900e+00,
        3.8390e+01, 7.6280e+01, 9.7580e+01, 9.9980e+01]])
for i in range(3):
  plt.loglog(np.logspace(1,5.5,10),1-0.01*layer2_zipf[i,:],color=colormap(i/3),linestyle="solid",marker=6)
  # plt.loglog(np.logspace(1,5.5,10),1-0.01*accurate_layer2_sim[i,:],color=colormap(i/3),linestyle="dotted",linewidth=2,marker=6)
def exp_prob(P,f_list):
  f_list=f_list
  exp=np.exp(-P*f_list/1000)
  sum=f_list@exp
  return (1-1*sum)**1

m=10
alpha=4
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)

ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
# plt.loglog(ptr_list,error_list,color=colormap(0/3),linestyle='dotted',linewidth=2)



m=10
alpha=0.8
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)
f_list1=f_list
ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
# plt.loglog(ptr_list,error_list,color=colormap(1/3),linestyle='dotted',linewidth=2)




m=10
alpha=0.2
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)
ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
# plt.loglog(ptr_list,error_list,color=colormap(2/3),linestyle='dotted',linewidth=2)


f_list=np.ones(m)/m
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
# plt.loglog(ptr_list,error_list,color="black",linestyle='dotted',linewidth=2)


# plt.gca().set_aspect('equal', adjustable='box')
# # Create legends for colors
# color_legend = [
#     plt.Line2D([0], [0], marker='o', color='white', markerfacecolor=colormap(0/3), markersize=8),
#     plt.Line2D([0], [0], marker='o', color='white', markerfacecolor=colormap(1/3), markersize=8),
#     plt.Line2D([0], [0], marker='o', color='white', markerfacecolor=colormap(2/3), markersize=8),
#     plt.Line2D([0], [0], marker='o', color='white', markerfacecolor="black", markersize=8)
# ]
# color_labels = [r'$\gamma=0.2$', r'$\gamma=0.63$', r'$\gamma=2$', r'uniform case']
# color_labels = [r'$\alpha=4$', r'$\alpha=0.8$',r'$\alpha=0.2$', r'uniform case']
# linestyle_legend = [
#     plt.Line2D([0], [0], linestyle="solid", color='black'),
#     plt.Line2D([0], [0], linestyle="dashdot", color='black'),
#     plt.Line2D([0], [0], linestyle="dotted", color='black')
# ]
# # linestyle_labels = ['Observed', 'Predicted']
# linestyle_labels = ['layer3', 'layer2','layer1']
# # Add legends
# plt.legend(linestyle_legend, linestyle_labels, loc='lower right')
# plt.legend(color_legend, color_labels, loc='lower right')
# plt.gca().add_artist(plt.legend(linestyle_legend + color_legend, linestyle_labels + color_labels, loc='lower left'))



# plt.xlabel("training points")
# plt.ylabel("test error")
# plt.grid()
# plt.title("m=10, Zipf-law in one layer, uniform sampling on other two layer")
# plt.gca().set_aspect('equal', adjustable='box')
# # plt.xlim(10**2.5,10**6)
# plt.ylim(10**(-3),1)





# def exp_prob(P,f_list):
#   f_list=f_list
#   exp=np.exp(-P*f_list/1000)
#   sum=f_list@exp
#   return (1-1*sum)**4

# m=10
# alpha=4
# f_list=np.zeros(m)
# for i in range(m):
#   f_list[i]=(i+1)**(-1-alpha)
# f_list/=np.sum(f_list)

# ptr_list=np.logspace(1,6.5,20)
# error_list=np.zeros(20)
# for i in range(20):
#   error_list[i]=1-exp_prob(ptr_list[i],f_list)
# # plt.loglog(ptr_list,error_list,color=colormap(0/3),linestyle='dashdot',linewidth=2)



# m=10
# alpha=0.8
# f_list=np.zeros(m)
# for i in range(m):
#   f_list[i]=(i+1)**(-1-alpha)
# f_list/=np.sum(f_list)
# f_list1=f_list
# ptr_list=np.logspace(1,6.5,20)
# error_list=np.zeros(20)
# for i in range(20):
#   error_list[i]=1-exp_prob(ptr_list[i],f_list)
# # plt.loglog(ptr_list,error_list,color=colormap(1/3),linestyle='dashdot',linewidth=2)




# m=10
# alpha=0.2
# f_list=np.zeros(m)
# for i in range(m):
#   f_list[i]=(i+1)**(-1-alpha)
# f_list/=np.sum(f_list)
# ptr_list=np.logspace(1,6.5,20)
# error_list=np.zeros(20)
# for i in range(20):
#   error_list[i]=1-exp_prob(ptr_list[i],f_list)
# # plt.loglog(ptr_list,error_list,color=colormap(2/3),linestyle='dashdot',linewidth=2)






color_legend = [
    plt.Line2D([0], [0], marker='.', color='white', markerfacecolor=colormap(0/3), markersize=8),
    plt.Line2D([0], [0], marker='.', color='white', markerfacecolor=colormap(1/3), markersize=8),
    plt.Line2D([0], [0], marker='.', color='white', markerfacecolor=colormap(2/3), markersize=8),
    plt.Line2D([0], [0], marker='.', color='white', markerfacecolor="black", markersize=8)
]
# color_labels = [r'$\gamma=0.2$', r'$\gamma=0.63$', r'$\gamma=2$', r'uniform case']
color_labels = [r'$\alpha=4$', r'$\alpha=0.8$',r"$\alpha=0.2$", r'uniform case']
marker_legend = [
    plt.Line2D([0], [0], marker=6, color='white', markerfacecolor="black", markersize=8),
    plt.Line2D([0], [0], marker='X', color='white', markerfacecolor="black", markersize=8),
    plt.Line2D([0], [0], marker='o', color='white', markerfacecolor="black", markersize=8),
    # plt.Line2D([0], [0], marker='o', color='white', markerfacecolor="black", markersize=8)
]
# color_labels = [r'$\gamma=0.2$', r'$\gamma=0.63$', r'$\gamma=2$', r'uniform case']
marker_labels = ["layer 1", "layer 2","layer 3"]
linestyle_legend = [
    plt.Line2D([0], [0], linestyle="solid", color='black'),
    # plt.Line2D([0], [0], linestyle="dashdot", color='black'),
    plt.Line2D([0], [0], linestyle="dotted", color='black'),
    # plt.Line2D([0], [0], linestyle='dotted', dashes=(1,5), color='black')
]
linestyle_labels = ['True', 'Predicted']
# Add legends
plt.legend(linestyle_legend, linestyle_labels, loc='lower right')
plt.legend(color_legend, color_labels, loc='lower right')
plt.legend(marker_legend, marker_labels, loc='lower right')
plt.gca().add_artist(plt.legend(linestyle_legend + color_legend+marker_legend, linestyle_labels + color_labels+marker_labels, loc='lower left'))



layer3_accurate=torch.tensor([[0.9968325, 0.9882325, 0.9631, 0.8850375, 0.69845, 0.3909625, 0.1861875, 0.074065, 0.018225, 0.0010525],
                             [0.996925, 0.988435, 0.9609, 0.8853425, 0.69651, 0.393715, 0.1838575, 0.0745825, 0.017695, 0.0009675],
                             [0.998105, 0.99331, 0.978385, 0.93369, 0.8093075, 0.5465675, 0.2646925, 0.075405, 0.00656, 5e-06]])
layer2_accurate=torch.tensor([[0.9916725, 0.97234, 0.910845, 0.74546, 0.3951025, 0.0774425, 0.0272125, 0.01655, 0.0057725, 0.0022775],
                              [0.9967425, 0.9885375, 0.9625625, 0.8847575, 0.6990875, 0.3943175, 0.1851725, 0.0749425, 0.01768, 0.0009725],
                              [0.997965, 0.9936575, 0.9783425, 0.93371, 0.80929, 0.5535825, 0.266015, 0.07651, 0.0059475, 2.5e-05]])
layer1_accurate=torch.tensor([[0.991255, 0.9723375, 0.9107, 0.7474925, 0.3997025, 0.0756175, 0.027765, 0.0166925, 0.0053975, 0.00239],
                              [0.9967525, 0.9882075, 0.96151, 0.8864075, 0.7008, 0.394335, 0.1833125, 0.0743425, 0.01769, 0.0011325],
                              [0.998005, 0.9934025, 0.978155, 0.9335, 0.8071425, 0.556725, 0.2656025, 0.0764875, 0.005605, 1e-05]])


plt.title("Zipf law on one layer, uniform sampling on other two layers, together with 1-shot path learner")
plt.xlabel("training points")
plt.ylabel("test error")
plt.xlim(10**2.5,10**6) 
plt.ylim(10**(-3),1)
plt.grid()


layer3_accurate=torch.tensor([[0.9968325, 0.9882325, 0.9631, 0.8850375, 0.69845, 0.3909625, 0.1861875, 0.074065, 0.018225, 0.0010525],
                             [0.996925, 0.988435, 0.9609, 0.8853425, 0.69651, 0.393715, 0.1838575, 0.0745825, 0.017695, 0.0009675],
                             [0.998105, 0.99331, 0.978385, 0.93369, 0.8093075, 0.5465675, 0.2646925, 0.075405, 0.00656, 5e-06]])
layer2_accurate=torch.tensor([[0.9916725, 0.97234, 0.910845, 0.74546, 0.3951025, 0.0774425, 0.0272125, 0.01655, 0.0057725, 0.0022775],
                              [0.9967425, 0.9885375, 0.9625625, 0.8847575, 0.6990875, 0.3943175, 0.1851725, 0.0749425, 0.01768, 0.0009725],
                              [0.997965, 0.9936575, 0.9783425, 0.93371, 0.80929, 0.5535825, 0.266015, 0.07651, 0.0059475, 2.5e-05]])
layer1_accurate=torch.tensor([[0.991255, 0.9723375, 0.9107, 0.7474925, 0.3997025, 0.0756175, 0.027765, 0.0166925, 0.0053975, 0.00239],
                              [0.9967525, 0.9882075, 0.96151, 0.8864075, 0.7008, 0.394335, 0.1833125, 0.0743425, 0.01769, 0.0011325],
                              [0.998005, 0.9934025, 0.978155, 0.9335, 0.8071425, 0.556725, 0.2656025, 0.0764875, 0.005605, 1e-05]])
for i in range(3):
  plt.loglog(np.logspace(1,5.5,10),layer3_accurate[i,:],color=colormap(i/3+0),linestyle="dotted")
  plt.loglog(np.logspace(1,5.5,10),layer2_accurate[i,:],color=colormap(i/3+0),linestyle="dotted")
  plt.loglog(np.logspace(1,5.5,10),layer1_accurate[i,:],color=colormap(i/3+0),linestyle="dotted")
# plt.legend()
# Out:
# C:\Users\alexk\AppData\Local\Temp\ipykernel_19352\2329508011.py:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = cm.get_cmap("hsv")

# %%
layer3_accurate=torch.tensor([[0.9968325, 0.9882325, 0.9631, 0.8850375, 0.69845, 0.3909625, 0.1861875, 0.074065, 0.018225, 0.0010525],
                             [0.996925, 0.988435, 0.9609, 0.8853425, 0.69651, 0.393715, 0.1838575, 0.0745825, 0.017695, 0.0009675],
                             [0.998105, 0.99331, 0.978385, 0.93369, 0.8093075, 0.5465675, 0.2646925, 0.075405, 0.00656, 5e-06]])
layer2_accurate=torch.tensor([[0.9916725, 0.97234, 0.910845, 0.74546, 0.3951025, 0.0774425, 0.0272125, 0.01655, 0.0057725, 0.0022775],
                              [0.9967425, 0.9885375, 0.9625625, 0.8847575, 0.6990875, 0.3943175, 0.1851725, 0.0749425, 0.01768, 0.0009725],
                              [0.997965, 0.9936575, 0.9783425, 0.93371, 0.80929, 0.5535825, 0.266015, 0.07651, 0.0059475, 2.5e-05]])
layer1_accurate=torch.tensor([[0.991255, 0.9723375, 0.9107, 0.7474925, 0.3997025, 0.0756175, 0.027765, 0.0166925, 0.0053975, 0.00239],
                              [0.9967525, 0.9882075, 0.96151, 0.8864075, 0.7008, 0.394335, 0.1833125, 0.0743425, 0.01769, 0.0011325],
                              [0.998005, 0.9934025, 0.978155, 0.9335, 0.8071425, 0.556725, 0.2656025, 0.0764875, 0.005605, 1e-05]])
for i in range(3):
  plt.loglog(np.logspace(1,5.5,10),layer3_accurate[i,:],color=colormap(i/3+0),linestyle="dashdot",marker='x')
  plt.loglog(np.logspace(1,5.5,10),layer2_accurate[i,:],color=colormap(i/3+0),linestyle="dotted",marker='o')
  plt.loglog(np.logspace(1,5.5,10),layer1_accurate[i,:],color=colormap(i/3+0),linestyle="solid",marker='d')
plt.grid()
plt.xlabel("training points")
plt.ylabel("test error")
plt.xlim(10**2.5, 10**5.5)
plt.ylim(10**(-3),1)
plt.title("predicted test error using simple BP error formula, Zipf-law on one layer, uniform sampling on other two layer ")
# Out:
# Text(0.5, 1.0, 'predicted test error using simple BP error formula, Zipf-law on one layer, uniform sampling on other two layer ')

# %%
import matplotlib.cm as cm
colormap = cm.get_cmap("hsv")

uniform_result=np.array([12.56, 13.39, 14.5, 15.96, 19.94, 39.42, 95.62, 99.96, 100.0, 100.0])
plt.plot(np.logspace(3,5,10),1-0.01*uniform_result, color="black")

def exp_prob(P,f_list):
  f_list=f_list
  exp=np.exp(-P*f_list/1000)
  sum=np.sum(f_list**4 *(1- 4* exp))
  return sum/np.sum(f_list**4)
  return (1-1*sum)**1

m=10
alpha=4
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)

ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color=colormap(0/3),linestyle='dotted',linewidth=2)



m=10
alpha=0.8
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)
f_list1=f_list
ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color=colormap(1/3),linestyle='dotted',linewidth=2)




m=10
alpha=0.2
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)
ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color=colormap(2/3),linestyle='dotted',linewidth=2)


f_list=np.ones(m)/m
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color="black",linestyle='dotted',linewidth=2)







def exp_prob(P,f_list):
  f_list=f_list
  exp=np.exp(-P*f_list/1000)
  sum=f_list@exp
  return (1-1*sum)**2

m=10
alpha=4
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)

ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color=colormap(0/3),linestyle='dashdot',linewidth=2)



m=10
alpha=0.8
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)
f_list1=f_list
ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color=colormap(1/3),linestyle='dashdot',linewidth=2)




m=10
alpha=0.2
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)
ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color=colormap(2/3),linestyle='dashdot',linewidth=2)

f_list=np.ones(m)/m
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color="black",linestyle='dashdot',linewidth=2)
def exp_prob(P,f_list):
  f_list=f_list
  exp=np.exp(-P*f_list/1000)
  sum=f_list@exp
  return (1-1*sum)**4

m=10
alpha=4
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)

ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color=colormap(0/3),linestyle='solid',linewidth=2)



m=10
alpha=0.8
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)
f_list1=f_list
ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color=colormap(1/3),linestyle='solid',linewidth=2)




m=10
alpha=0.2
f_list=np.zeros(m)
for i in range(m):
  f_list[i]=(i+1)**(-1-alpha)
f_list/=np.sum(f_list)
ptr_list=np.logspace(1,6.5,20)
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color=colormap(2/3),linestyle='solid',linewidth=2)


f_list=np.ones(m)/m
error_list=np.zeros(20)
for i in range(20):
  error_list[i]=1-exp_prob(ptr_list[i],f_list)
plt.loglog(ptr_list,error_list,color="black",linestyle='solid',linewidth=2)









plt.gca().set_aspect('equal', adjustable='box')
# Create legends for colors
color_legend = [
    plt.Line2D([0], [0], marker='o', color='white', markerfacecolor=colormap(0/3), markersize=8),
    plt.Line2D([0], [0], marker='o', color='white', markerfacecolor=colormap(1/3), markersize=8),
    plt.Line2D([0], [0], marker='o', color='white', markerfacecolor=colormap(2/3), markersize=8),
    plt.Line2D([0], [0], marker='o', color='white', markerfacecolor="black", markersize=8)
]
color_labels = [r'$\gamma=0.2$', r'$\gamma=0.63$', r'$\gamma=2$', r'uniform case']
color_labels = [r'$\alpha=4$', r'$\alpha=0.8$',r'$\alpha=0.2$', r'uniform case']
linestyle_legend = [
    plt.Line2D([0], [0], linestyle="solid", color='black'),
    plt.Line2D([0], [0], linestyle="dashdot", color='black'),
    plt.Line2D([0], [0], linestyle="dotted", color='black')
]
# linestyle_labels = ['Observed', 'Predicted']
linestyle_labels = ['layer3', 'layer2','layer1']
# Add legends
plt.legend(linestyle_legend, linestyle_labels, loc='lower right')
plt.legend(color_legend, color_labels, loc='lower right')
plt.gca().add_artist(plt.legend(linestyle_legend + color_legend, linestyle_labels + color_labels, loc='lower left'))



plt.xlabel("training points")
plt.ylabel("test error")
plt.grid()
plt.title("m=10, Zipf-law in one layer, uniform sampling on other two layer,only prediction")
plt.gca().set_aspect('equal', adjustable='box')
plt.xlim(10**2.5,10**6)
plt.ylim(10**(-3),1)
# Out:
# <ipython-input-30-4a45f737e57b>:2: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colormap = cm.get_cmap("hsv")
# (0.001, 1)
